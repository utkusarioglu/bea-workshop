# %% [markdown]
# ### Library imports

# %%
import numpy as np
import pandas as pd
import requests
from math import floor
from scipy import stats
import pprint
from dotenv import dotenv_values
from econ_utils import chunks, check_divide_by_zero, iex_cloud_api
from scipy.stats import percentileofscore as score
from constants import STATS_COLS, MARKET_COLS

config = dotenv_values()
pp = pprint.PrettyPrinter(indent=2)

# %%
sp100_df = pd.read_excel("../data/SP100.xlsx")
sp100_df
# Out:
#     Symbol              Company Name                  Sector
# 0     AAPL                     Apple  Information Technology
# 1     ABBV                    AbbVie             Health Care
# 2      ABT                    Abbott             Health Care
# 3      ACN                 Accenture  Information Technology
# 4     ADBE                     Adobe  Information Technology
# ..     ...                       ...                     ...
# 96      VZ                   Verizon  Communication Services
# 97     WBA  Walgreens Boots Alliance        Consumer Staples
# 98     WFC               Wells Fargo              Financials
# 99     WMT                   Walmart        Consumer Staples
# 100    XOM                ExxonMobil                  Energy
#
# [101 rows x 3 columns]

# %% [markdown]
# ### Method for all SP 500 stocks

# %%
symbol_chunks = list(chunks(sp100_df["Symbol"], 100))
symbol_csv_list = []

for i in range(0, len(symbol_chunks)):
  symbol_csv_list.append(",".join(symbol_chunks[i]))

# %%
market_responses = []
for symbol_csv in symbol_csv_list:
  response = iex_cloud_api("stock/market/batch", symbols=symbol_csv, types="quote")
  market_responses.append(response)

# %%
stocks_df = pd.DataFrame(columns=MARKET_COLS.values())

# #1 TODO find out what kind of errors can be thrown here
for response in market_responses:
  for symbol in response.keys():
    try:
      quote = response[symbol]["quote"].values()
      stocks_df.loc[symbol] = pd.Series(quote, index=MARKET_COLS.values())
    except: # #1
      print(f"Symbol {symbol} failed: {quote}")
stocks_df
# Out:
#      Average Total Volume Calculation Price Change Change % Close  \
# AAPL             80930748              tops  -1.14 -0.00685  None
# ABBV              7643404              tops  -2.18 -0.01375  None
# ABT               4961556              tops  -3.02 -0.02448  None
# ACN               2196120              tops  -5.45 -0.01691  None
# ADBE              3126202              tops  -2.02 -0.00484  None
# ...                   ...               ...    ...      ...   ...
# VZ               23576485              tops  -2.91  -0.0529  None
# WBA               8093422              tops  -0.71 -0.01517  None
# WFC              26528316              tops  -0.21  -0.0044  None
# WMT               7244939              tops  -0.47 -0.00294  None
# XOM              22755127              tops   0.42  0.00483  None
#
#      Close Source Close Time                  Company Name Currency  \
# AAPL     official       None                     Apple Inc      USD
# ABBV     official       None                    Abbvie Inc      USD
# ABT      official       None           Abbott Laboratories      USD
# ACN      official       None       Accenture plc - Class A      USD
# ADBE     official       None                     Adobe Inc      USD
# ...           ...        ...                           ...      ...
# VZ       official       None    Verizon Communications Inc      USD
# WBA      official       None  Walgreens Boots Alliance Inc      USD
# WFC      official       None             Wells Fargo & Co.      USD
# WMT      official       None                   Walmart Inc      USD
# XOM      official       None             Exxon Mobil Corp.      USD
#
#      Delayed Price  ... PE Ratio Previous Close Previous Volume  \
# AAPL          None  ...    27.46         166.42        87227768
# ABBV          None  ...    24.24         158.52         7903316
# ABT           None  ...    30.47         123.37         7321143
# ACN           None  ...    31.97         322.31         1910213
# ADBE          None  ...    41.22         417.48         2390149
# ...            ...  ...      ...            ...             ...
# VZ            None  ...     9.79          55.01        32821141
# WBA           None  ...     6.36          46.81         7106024
# WFC           None  ...     9.61          47.78        19027637
# WMT           None  ...    32.73         159.87         6056100
# XOM           None  ...    16.22          87.03        29010859
#
#                   Primary Exchange Symbol Volume 52 Week High 52 Week Low  \
# AAPL                        NASDAQ   AAPL   None       182.71      121.73
# ABBV  NEW YORK STOCK EXCHANGE INC.   ABBV   None       174.43      102.35
# ABT   NEW YORK STOCK EXCHANGE INC.    ABT   None       141.53      103.78
# ACN   NEW YORK STOCK EXCHANGE INC.    ACN   None       415.05      273.76
# ADBE                        NASDAQ   ADBE   None       699.54      407.94
# ...                            ...    ...    ...          ...         ...
# VZ    NEW YORK STOCK EXCHANGE INC.     VZ   None        57.74        48.5
# WBA                         NASDAQ    WBA   None        54.45        42.9
# WFC   NEW YORK STOCK EXCHANGE INC.    WFC   None         60.3       40.95
# WMT   NEW YORK STOCK EXCHANGE INC.    WMT   None       160.77       131.5
# XOM   NEW YORK STOCK EXCHANGE INC.    XOM   None        91.51       50.85
#
#      Year-to-date Change Is US Market Open
# AAPL           -0.068448              True
# ABBV            0.179205              True
# ABT            -0.141301              True
# ACN             -0.23508              True
# ADBE           -0.268622              True
# ...                  ...               ...
# VZ              0.031601              True
# WBA            -0.108699              True
# WFC            -0.004096              True
# WMT             0.106248              True
# XOM             0.442888              True
#
# [101 rows x 56 columns]

# %%
position_size = 1e6
stocks_df["Shares to buy"] = (position_size * stocks_df[MARKET_COLS["latestPrice"]] / stocks_df[MARKET_COLS["latestPrice"]].sum())
top_20_pe_stocks = stocks_df.sort_values(MARKET_COLS["peRatio"], ascending=False).head(20)
top_20_pe_stocks
# Out:
#      Average Total Volume Calculation Price Change Change % Close  \
# TSLA             22880399              tops   4.46  0.00442  None
# CRM               5852779              tops  -2.91 -0.01642  None
# BKNG               326574              tops  10.83  0.00484  None
# DIS              10925277              tops -0.765 -0.00629  None
# TMUS              4960686              tops  -2.49 -0.01885  None
# KHC               5819140              tops -0.075  -0.0017  None
# NVDA             54915672              tops  -2.51 -0.01244  None
# COST              2374253              tops  -8.55 -0.01445  None
# AMT               1823217              tops  -2.18 -0.00817  None
# LLY               2692400              tops  -5.18 -0.01789  None
# AMZN              2848406              tops -13.36  -0.0045  None
# LIN               1679875              tops  -7.52 -0.02318  None
# MO                7831302              tops  -0.34 -0.00601  None
# NEE               7767748              tops  -0.81 -0.01063  None
# ADBE              3126202              tops  -2.02 -0.00484  None
# MA                3106138              tops  -9.09 -0.02494  None
# EXC               7469576              tops  -0.03  -0.0006  None
# RTX               4672169              tops  -0.23 -0.00226  None
# V                 6838556              tops   -4.3 -0.01987  None
# NKE               6295832              tops  -2.99 -0.02207  None
#
#      Close Source Close Time                       Company Name Currency  \
# TSLA     official       None                          Tesla Inc      USD
# CRM      official       None                     Salesforce Inc      USD
# BKNG     official       None               Booking Holdings Inc      USD
# DIS      official       None               Walt Disney Co (The)      USD
# TMUS     official       None                    T-Mobile US Inc      USD
# KHC      official       None                     Kraft Heinz Co      USD
# NVDA     official       None                        NVIDIA Corp      USD
# COST     official       None              Costco Wholesale Corp      USD
# AMT      official       None               American Tower Corp.      USD
# LLY      official       None                    Lilly(Eli) & Co      USD
# AMZN     official       None                    Amazon.com Inc.      USD
# LIN      official       None                          Linde Plc      USD
# MO       official       None                  Altria Group Inc.      USD
# NEE      official       None                 NextEra Energy Inc      USD
# ADBE     official       None                          Adobe Inc      USD
# MA       official       None  Mastercard Incorporated - Class A      USD
# EXC      official       None                       Exelon Corp.      USD
# RTX      official       None  Raytheon Technologies Corporation      USD
# V        official       None                 Visa Inc - Class A      USD
# NKE      official       None               Nike, Inc. - Class B      USD
#
#      Delayed Price  ... Previous Close Previous Volume  \
# TSLA          None  ...        1008.78        35138779
# CRM           None  ...         177.23         9119512
# BKNG          None  ...        2239.32          389840
# DIS           None  ...         121.66        18688636
# TMUS          None  ...          132.1         3580745
# KHC           None  ...             44         9219449
# NVDA          None  ...         201.83        65620944
# COST          None  ...         591.74         2027947
# AMT           None  ...         266.75         1712477
# LLY           None  ...         289.61         2716751
# AMZN          None  ...        2965.92         3198466
# LIN           None  ...         324.37         1475038
# MO            None  ...          56.53         8659828
# NEE           None  ...          76.18        17712832
# ADBE          None  ...         417.48         2390149
# MA            None  ...         364.44         3605298
# EXC           None  ...          49.74         5337290
# RTX           None  ...         101.73         5795338
# V             None  ...         216.45         8850268
# NKE           None  ...         135.46         6562404
#
#                   Primary Exchange Symbol Volume 52 Week High 52 Week Low  \
# TSLA                        NASDAQ   TSLA   None      1243.49      546.98
# CRM   NEW YORK STOCK EXCHANGE INC.    CRM   None       311.75      174.23
# BKNG                        NASDAQ   BKNG   None      2715.66     1796.45
# DIS   NEW YORK STOCK EXCHANGE INC.    DIS   None       189.22       119.7
# TMUS                        NASDAQ   TMUS   None        150.2      101.51
# KHC                         NASDAQ    KHC   None        44.48       32.44
# NVDA                        NASDAQ   NVDA   None       346.37       134.5
# COST                        NASDAQ   COST   None       612.27      362.69
# AMT   NEW YORK STOCK EXCHANGE INC.    AMT   None       299.22      218.83
# LLY   NEW YORK STOCK EXCHANGE INC.    LLY   None          314      175.91
# AMZN                        NASDAQ   AMZN   None      3773.08     2671.45
# LIN   NEW YORK STOCK EXCHANGE INC.    LIN   None       350.77      266.44
# MO    NEW YORK STOCK EXCHANGE INC.     MO   None        57.05       41.02
# NEE   NEW YORK STOCK EXCHANGE INC.    NEE   None        93.21       69.41
# ADBE                        NASDAQ   ADBE   None       699.54      407.94
# MA    NEW YORK STOCK EXCHANGE INC.     MA   None       399.91      305.18
# EXC                         NASDAQ    EXC   None        50.71       29.65
# RTX   NEW YORK STOCK EXCHANGE INC.    RTX   None       106.02       76.99
# V     NEW YORK STOCK EXCHANGE INC.      V   None       251.47      186.67
# NKE   NEW YORK STOCK EXCHANGE INC.    NKE   None       178.37      116.75
#
#      Year-to-date Change Is US Market Open  Shares to buy
# TSLA           -0.041001              True   36591.161554
# CRM            -0.319021              True    6295.222536
# BKNG           -0.061811              True   81259.723432
# DIS            -0.220829              True     4365.88417
# TMUS            0.120139              True    4680.609183
# KHC             0.236903              True    1586.264628
# NVDA           -0.326083              True    7198.048163
# COST            0.029476              True   21060.755109
# AMT            -0.091329              True    9554.423051
# LLY             0.034963              True    10271.62773
# AMZN           -0.114993              True  106625.873394
# LIN            -0.083101              True   11442.412003
# MO              0.207377              True     2029.19088
# NEE             -0.19013              True    2721.838702
# ADBE           -0.268622              True   15003.517409
# MA             -0.007951              True    12832.76347
# EXC             0.217297              True    1795.178478
# RTX             0.186394              True    3665.472048
# V              -0.019445              True    7661.378275
# NKE            -0.207472              True    4783.892435
#
# [20 rows x 57 columns]

# %%
stats_df = pd.DataFrame(columns=STATS_COLS.values())
for symbol in top_20_pe_stocks[MARKET_COLS["symbol"]]:
  response = iex_cloud_api(f"stock/{symbol}/stats")
  stats_df.loc[symbol] = pd.Series([
    symbol,
    *response.values()
  ], index=STATS_COLS.values()) 
stats_df
# Out:
#      Symbol                       Company Name     Market Cap 52 Week High  \
# TSLA   TSLA                          Tesla Inc  1013082297401      1243.49
# CRM     CRM                     Salesforce Inc   175457700000       311.75
# BKNG   BKNG               Booking Holdings Inc    91954283230      2715.66
# DIS     DIS               Walt Disney Co (The)   221498260417       189.22
# TMUS   TMUS                    T-Mobile US Inc   165031202923        150.2
# KHC     KHC                     Kraft Heinz Co    53895342248        44.48
# NVDA   NVDA                        NVIDIA Corp   587881446602       346.37
# COST   COST              Costco Wholesale Corp   262273541365       612.27
# AMT     AMT               American Tower Corp.   121702027202       299.22
# LLY     LLY                    Lilly(Eli) & Co   275809251161          314
# AMZN   AMZN                    Amazon.com Inc.  1508536883985      3773.08
# LIN     LIN                          Linde Plc   166257378094       350.77
# MO       MO                  Altria Group Inc.   102472457351        57.05
# NEE     NEE                 NextEra Energy Inc   149241948943        93.21
# ADBE   ADBE                          Adobe Inc   197259300000       699.54
# MA       MA            Mastercard Incorporated   353408202580       399.91
# EXC     EXC                       Exelon Corp.    48752012788        50.71
# RTX     RTX  Raytheon Technologies Corporation   151605001992       106.02
# V         V                           Visa Inc   477055800000       251.47
# NKE     NKE                         Nike, Inc.   212649173967       178.37
#
#      52 Week Low 52 Week High Split Adjust Only 52 Week Low Split Adjust Only  \
# TSLA      546.98                        1243.49                        546.98
# CRM       176.74                         311.75                        176.74
# BKNG     1796.45                        2715.66                       1796.45
# DIS       121.28                         189.22                        121.28
# TMUS      101.51                          150.2                        101.51
# KHC        32.44                          44.95                         32.78
# NVDA       134.5                         346.47                        134.59
# COST      362.69                         612.27                        365.29
# AMT       218.83                         303.72                           220
# LLY       175.91                            314                        178.58
# AMZN     2671.45                        3773.08                       2671.45
# LIN       266.44                         352.18                        267.51
# MO         41.02                          57.05                         42.53
# NEE        69.41                          93.73                         69.79
# ADBE      407.94                         699.54                        407.94
# MA        305.18                          401.5                        305.61
# EXC        29.65                          50.71                         30.51
# RTX        76.99                         106.02                         78.81
# V         186.67                         252.67                        186.67
# NKE       116.75                          179.1                        116.75
#
#      52 Week Change Outstanding Shares Float  ... Max Change %  \
# TSLA       0.401687         1004264852     0  ...    210.13018
# CRM       -0.233931          990000000     0  ...    18.449108
# BKNG        -0.0459           41063485     0  ...    50.348773
# DIS       -0.334318         1820633408     0  ...     3.176479
# TMUS       0.002809         1249289954     0  ...     7.101213
# KHC        0.120015         1224894142     0  ...    -0.200531
# NVDA       0.360051         2912755520     0  ...    34.624393
# COST       0.605296          443224290     0  ...    14.219454
# AMT        0.081582          456240027     0  ...     4.459107
# LLY        0.571766          952347126     0  ...     7.851215
# AMZN      -0.103692          508623592     0  ...    74.162696
# LIN        0.139663          512554731     0  ...     1.080627
# MO         0.305992         1812709311     0  ...     0.852167
# NEE        -0.01311         1964439781     0  ...     1.476879
# ADBE      -0.177039          472500000     0  ...     9.152724
# MA         -0.04558          969729455     0  ...    38.354672
# EXC        0.598206          980136968     0  ...     0.951637
# RTX        0.322536         1490268377     0  ...     1.453107
# V          -0.04295         1658423632     0  ...    10.076087
# NKE        0.056761         1268760217     0  ...    11.870187
#
#      5 Year Change % 2 Year Change % 1 Year Change % Year-to-date Change %  \
# TSLA       15.504908        6.344915        0.355668             -0.045421
# CRM         1.115169        0.177139       -0.231306             -0.302601
# BKNG        0.278143         0.66837       -0.050222             -0.066651
# DIS         0.110137        0.210066       -0.335591             -0.214539
# TMUS        1.068497        0.534416       -0.000151              0.138989
# KHC        -0.399064        0.688379        0.103584              0.238603
# NVDA        7.035689        2.001788        0.314872             -0.313643
# COST        2.877018         1.04661        0.593152              0.043926
# AMT         1.364285        0.146664        0.078837             -0.083159
# LLY         2.929185        0.962361        0.539664              0.052853
# AMZN        2.300858        0.273955       -0.117816             -0.110493
# LIN         1.080627        0.869894        0.126899             -0.059921
# MO          0.092281        0.740445        0.276349              0.213387
# NEE         1.558866        0.340397        -0.00868               -0.1795
# ADBE         2.17427        0.268975        -0.18515             -0.263782
# MA          2.267741        0.498686       -0.044933              0.016989
# EXC         1.342668        1.100347        0.577215              0.217897
# RTX         0.181665        0.712148        0.320356              0.188654
# V            1.45208        0.365222       -0.042446              0.000425
# NKE         1.546126        0.616333        0.050904             -0.185402
#
#      6 Month Change % 3 Month Change % 1 Month Change % 30 Day Change %  \
# TSLA         0.128389         0.068736         0.095119         0.01489
# CRM         -0.388461        -0.189361        -0.170737       -0.187801
# BKNG        -0.071257        -0.045416         0.036056        0.016967
# DIS          -0.28995        -0.114427        -0.122349       -0.131682
# TMUS         0.130509         0.299941         0.048662        0.050998
# KHC          0.236063         0.201779         0.169591         0.15942
# NVDA        -0.110307        -0.136372        -0.245044       -0.239067
# COST         0.243836         0.230533         0.065181        0.057774
# AMT          -0.03416         0.095669         0.109816        0.118938
# LLY          0.209783          0.19649        -0.000104        0.016104
# AMZN        -0.136561          0.03963         -0.08171       -0.100631
# LIN          0.049628         0.030215         0.043997        0.039214
# MO           0.215148         0.142736         0.100525        0.078642
# NEE         -0.081956        -0.072615        -0.068704       -0.080507
# ADBE        -0.346319         -0.16489        -0.079609       -0.104984
# MA           0.025869         0.027785         0.056039        0.044104
# EXC          0.387138         0.239135         0.139258        0.140041
# RTX          0.123192          0.17298         0.017911        0.003452
# V           -0.056707         0.052795        -0.002718       -0.009246
# NKE         -0.161345        -0.050234         0.040479        0.017807
#
#      5 Day Change %
# TSLA       0.024142
# CRM       -0.064305
# BKNG       0.005401
# DIS       -0.067525
# TMUS      -0.006468
# KHC        0.040435
# NVDA      -0.050569
# COST       0.002287
# AMT        0.043868
# LLY       -0.040582
# AMZN      -0.022481
# LIN        0.018366
# MO         0.028192
# NEE       -0.080063
# ADBE       -0.00704
# MA         0.018501
# EXC        0.014481
# RTX        -0.02436
# V            0.0172
# NKE        0.014986
#
# [20 rows x 33 columns]

# %% [markdown]
# ### Removing glamour stocks

# %%
both = pd.concat([top_20_pe_stocks, stats_df], axis=1)
both = both.loc[:, ~both.columns.duplicated()]
both[[MARKET_COLS[col] for col in ["symbol", "peRatio", "week52High", "volume"]]]
# Out:
#      Symbol PE Ratio 52 Week High Volume
# TSLA   TSLA   207.21      1243.49   None
# CRM     CRM   117.78       311.75   None
# BKNG   BKNG    79.88      2715.66   None
# DIS     DIS    71.96       189.22   None
# TMUS   TMUS    53.78        150.2   None
# KHC     KHC    53.65        44.48   None
# NVDA   NVDA    51.77       346.37   None
# COST   COST    47.03       612.27   None
# AMT     AMT    46.74       299.22   None
# LLY     LLY    46.48          314   None
# AMZN   AMZN    45.58      3773.08   None
# LIN     LIN    43.23       350.77   None
# MO       MO    41.93        57.05   None
# NEE     NEE    41.64        93.21   None
# ADBE   ADBE    41.22       699.54   None
# MA       MA    40.57       399.91   None
# EXC     EXC    40.09        50.71   None
# RTX     RTX    39.65       106.02   None
# V         V    35.12       251.47   None
# NKE     NKE    35.04       178.37   None

# %%
final_dataframe.sort_values(COLUMNS[2], inplace = True)
final_dataframe = final_dataframe[final_dataframe[COLUMNS[2]] > 0][:50]
final_dataframe.reset_index(drop = True, inplace = True)
final_dataframe
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /usr/src/app/workshop/economics/src/value-strategy.ipynb Cell 10' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://dev-container%2B5c5c77736c2e6c6f63616c686f73745c5562756e74752d32302e30345c686f6d655c75746b75736172696f676c755c776f726b73686f70735c65636f6e6f6d696373/usr/src/app/workshop/economics/src/value-strategy.ipynb#ch0000009vscode-remote?line=0'>1</a> final_dataframe.sort_values(COLUMNS[2], inplace = True)
#       <a href='vscode-notebook-cell://dev-container%2B5c5c77736c2e6c6f63616c686f73745c5562756e74752d32302e30345c686f6d655c75746b75736172696f676c755c776f726b73686f70735c65636f6e6f6d696373/usr/src/app/workshop/economics/src/value-strategy.ipynb#ch0000009vscode-remote?line=1'>2</a> final_dataframe = final_dataframe[final_dataframe[COLUMNS[2]] > 0][:50]
#       <a href='vscode-notebook-cell://dev-container%2B5c5c77736c2e6c6f63616c686f73745c5562756e74752d32302e30345c686f6d655c75746b75736172696f676c755c776f726b73686f70735c65636f6e6f6d696373/usr/src/app/workshop/economics/src/value-strategy.ipynb#ch0000009vscode-remote?line=2'>3</a> final_dataframe.reset_index(drop = True, inplace = True)
#
# NameError: name 'final_dataframe' is not defined

# %% [markdown]
# ### Calculating the number of shares to buy

# %%
portfolio_size = 2

# %%
position_size = portfolio_size/len(final_dataframe)
for row in final_dataframe.index:
  final_dataframe.loc[row, COLUMNS[3]] = floor(position_size / final_dataframe.loc[row, COLUMNS[1]])
final_dataframe
# Out:
#    Ticker Latest Price Price-to-Earnings Ratio Number of Shares to Buy
# 0       F        15.48                    3.48                       0
# 1     COF       132.59                    4.92                       0
# 2       C        50.93                    5.03                       0
# 3      GS       321.64                    5.41                       0
# 4      DD         68.7                    5.78                       0
# 5     AIG        63.03                    5.83                       0
# 6      GM        40.13                    5.99                       0
# 7     WBA        44.81                    6.18                       0
# 8       T        19.54                    7.08                       0
# 9     DOW        65.49                    7.77                       0
# 10    JPM       126.12                    8.21                       0
# 11    WFC        46.35                    9.36                       0
# 12   INTC        45.67                     9.4                       0
# 13    MET        70.64                    9.66                       0
# 14     VZ        53.83                   10.12                       0
# 15    USB        52.71                   10.34                       0
# 16    BAC        37.57                   10.52                       0
# 17     MS        84.76                   10.56                       0
# 18    FDX       205.74                   10.75                       0
# 19     BK        47.29                    11.4                       0
# 20   GILD        61.82                   12.54                       0
# 21    UPS       188.02                   12.81                       0
# 22    PFE        53.12                    13.8                       0
# 23    MMM       147.38                   14.56                       0
# 24     FB       210.18                   15.26                       0
# 25  CMCSA        47.58                   15.65                       0
# 26   QCOM       136.91                    15.7                       0
# 27    XOM        87.83                   16.29                       0
# 28    COP       101.37                   16.67                       0
# 29    LOW       201.28                   16.73                       0
# 30    TGT        237.2                   16.82                       0
# 31    MRK        86.91                   16.91                       0
# 32    CVS       103.68                   17.43                       0
# 33     PM       101.77                   17.46                       0
# 34    BLK       688.17                   18.01                       0
# 35    AXP       181.16                   18.08                       0
# 36   CSCO        51.17                   18.28                       0
# 37    SPG       127.88                    18.7                       0
# 38    CAT       227.81                   19.26                       0
# 39     HD       304.52                   19.61                       0
# 40    IBM       126.56                   19.93                       0
# 41    EMR        92.86                   20.28                       0
# 42    LMT       467.66                   20.55                       0
# 43   MDLZ        63.72                   20.96                       0
# 44    TXN       173.66                   21.02                       0
# 45    CVX       171.59                   21.08                       0
# 46     GD       243.74                    21.1                       0
# 47   SBUX         79.5                   21.43                       0
# 48    JNJ        179.9                   23.03                       0
# 49   CHTR       555.32                   23.03                       0

# %% [markdown]
# ## A more realistic strategy
#
# With this method, we will use the following values to create our strategy
#
# * Price-to-earnings ratio
# * Price-to-book ratio
# * Price-to-sales ratio
# * Enterprise value divided by Earnings before interest, taxes, deprecation and amortization (EV/EBITDA)
# * Enterprise value divided by Gross Profit (EV/GP)
#
# ### Single api call

# %%
symbol = 'AAPL'
types = 'advanced-stats'
params= f'symbols={symbol}&types={types}&token={IEX_CLOUD_API_TOKEN}'
batch_api_url = f'{API_BASE}/{BATCH_API_EP}?{params}'
data = requests.get(batch_api_url).json()
adv_stats = data[symbol]['advanced-stats']

# Price-to-earnings ratio
pe_ratio = adv_stats['peRatio']

# Price-to-book ratio
pb_ratio = adv_stats['priceToBook']

# Price-to-sales ratio
ps_ratio = adv_stats['priceToSales']

#Enterprise value divided by Earnings before interest, taxes, deprecation and amortization (EV/EBITDA)
ev_to_ebitda = adv_stats['enterpriseValue'] / adv_stats['EBITDA']

#Enterprise value divided by Gross Profit (EV/GP)
ev_to_gp = adv_stats['enterpriseValue'] / adv_stats['grossProfit']

pp.pprint({
    'pe_ratio': pe_ratio, 
    'pb_ratio': pb_ratio, 
    'ps_ratio':ps_ratio, 
    'ev_to_ebitda': ev_to_ebitda, 
    'ev_to_gp': ev_to_gp
})
# Out:
# { 'ev_to_ebitda': 24.341755451720832,
#   'ev_to_gp': 18.222892317069064,
#   'pb_ratio': 31.85,
#   'pe_ratio': 31.939737223081785,
#   'ps_ratio': 7.26}

# %%
rv_columns = [
    'Ticker',
    'Price',
    'Number of Shares to Buy',
    'Price-to-earnings Ratio',
    'PE Percentile',
    'Price-to-Book Ratio',
    'PB Percentile',
    'Price-to-sales Ratio',
    'PS Percentile',
    'EV/EBITDA',
    'EV/EBITDA Percentile',
    'EV/GP',
    'EV/GP Percentile',
    'RV Score'
]

rv_dataframe = pd.DataFrame(columns = rv_columns)
rv_dataframe
# Out:
# Empty DataFrame
# Columns: [Ticker, Price, Number of Shares to Buy, Price-to-earnings Ratio, PE Percentile, Price-to-Book Ratio, PB Percentile, Price-to-sales Ratio, PS Percentile, EV/EBITDA, EV/EBITDA Percentile, EV/GP, EV/GP Percentile, RV Score]
# Index: []

# %%
types = 'quote,advanced-stats'

symbol_csv_chunks = chunks(stocks, 100)
symbol_csv_list = []

for i in range(0, len(symbol_chunks)):
    symbol_csv_list.append(','.join(symbol_chunks[i]))
    
for symbol_csv in symbol_csv_list:
    params= f'symbols={symbol_csv}&types={types}&token={IEX_CLOUD_API_TOKEN}'
    batch_api_url = f'{API_BASE}/{BATCH_API_EP}?{params}'
    data = requests.get(batch_api_url).json()

    for symbol in symbol_csv.split(','):
        quote = data[symbol]['quote']
        adv_stats = data[symbol]['advanced-stats']
        
        rv_dataframe = rv_dataframe.append(
            pd.Series(
                [
                    symbol, # Ticker
                    quote['latestPrice'], # Price
                    floor(position_size/quote['latestPrice']), # Number of Shares to Buy
                    adv_stats['peRatio'], # Price-to-earnings Ratio
                    'N/A', # PE Percentile
                    adv_stats['priceToBook'], # Price-to-Book Ratio
                    'N/A', # PB Percentile
                    adv_stats['priceToSales'], # Price-to-sales Ratio
                    'N/A', # PS Percentile
                    divide_check_for_none(adv_stats['enterpriseValue'], adv_stats['EBITDA']), # EV/EBITDA
                    'N/A', # EV/EBITDA Percentile
                    divide_check_for_none(adv_stats['enterpriseValue'], adv_stats['grossProfit']), # EV/GP
                    'N/A', # EV/GP Percentile
                    'N/A', # RV Score
                ],
                index = rv_columns
            ),
            ignore_index = True
        )
rv_dataframe
# Out:
#      Ticker   Price Number of Shares to Buy Price-to-earnings Ratio  \
# 0         A  126.45                    1581               48.678233
# 1       AAL   23.73                    8428               -1.724898
# 2       AAP  193.57                    1033               25.957606
# 3      AAPL  123.85                    1614                32.64429
# 4      ABBV  107.37                    1862               41.725936
# ...     ...     ...                     ...                     ...
# 1510    YUM  109.30                    1829               36.676953
# 1511    ZBH  162.79                    1228              -252.45844
# 1512   ZBRA  479.58                     417                51.70243
# 1513   ZION   57.51                    3477                 8.87294
# 1514    ZTS  159.82                    1251               45.917379
#
#      PE Percentile Price-to-Book Ratio PB Percentile Price-to-sales Ratio  \
# 0              N/A                8.03           N/A                 7.11
# 1              N/A               -2.14           N/A                0.887
# 2              N/A                3.56           N/A                 1.26
# 3              N/A                32.2           N/A                 7.14
# 4              N/A                14.5           N/A                 4.24
# ...            ...                 ...           ...                  ...
# 1510           N/A               -4.18           N/A                 5.85
# 1511           N/A                2.84           N/A                 4.89
# 1512           N/A               12.39           N/A                 5.76
# 1513           N/A                1.29           N/A                 2.63
# 1514           N/A               20.28           N/A                11.36
#
#      PS Percentile  EV/EBITDA EV/EBITDA Percentile      EV/GP  \
# 0              N/A  30.232171                  N/A  13.242361
# 1              N/A  -4.467264                  N/A   2.328124
# 2              N/A  12.380167                  N/A   2.703519
# 3              N/A  24.005723                  N/A  18.023512
# 4              N/A   13.74106                  N/A   8.842531
# ...            ...        ...                  ...        ...
# 1510           N/A  24.395346                  N/A  10.163196
# 1511           N/A   30.32078                  N/A   8.560155
# 1512           N/A  35.033003                  N/A  13.142599
# 1513           N/A   6.814162                  N/A   3.002063
# 1514           N/A  31.211456                  N/A  16.721655
#
#      EV/GP Percentile RV Score
# 0                 N/A      N/A
# 1                 N/A      N/A
# 2                 N/A      N/A
# 3                 N/A      N/A
# 4                 N/A      N/A
# ...               ...      ...
# 1510              N/A      N/A
# 1511              N/A      N/A
# 1512              N/A      N/A
# 1513              N/A      N/A
# 1514              N/A      N/A
#
# [1515 rows x 14 columns]

# %%
rv_dataframe[rv_dataframe.isnull().any(axis = 1)]
# Out:
#      Ticker     Price Number of Shares to Buy Price-to-earnings Ratio  \
# 545     AON   236.260                     846                    None
# 547     APA    19.140                   10449                    None
# 576   BRK.B   267.640                     747                    None
# 623     CTL    11.000                   18181                    None
# 641   DISCK    36.330                    5505                    None
# 670    ETFC    50.370                    3970                    None
# 673    EVRG    59.270                    3374                    None
# 695     FOX    37.290                    5363                    None
# 697     FRC   174.230                    1147                    None
# 709    GOOG  2074.720                      96                    None
# 831     MYL    16.037                   12471                    None
# 832     NBL     8.660                   23094                    None
# 853     NWS    24.500                    8163                    None
# 868     PEG    59.800                    3344                    None
# 947    TROW   186.070                    1074                    None
# 957      UA    19.090                   10476                    None
# 959     UAL    57.100                    3502                    None
# 1003    XRX    25.960                    7704                    None
# 1050    AON   238.840                     837                    None
# 1052    APA    18.890                   10587                    None
# 1081  BRK.B   266.290                     751                    None
# 1128    CTL    11.000                   18181                    None
# 1146  DISCK    36.720                    5446                    None
# 1175   ETFC    49.480                    4042                    None
# 1178   EVRG    61.160                    3270                    None
# 1200    FOX    37.680                    5307                    None
# 1202    FRC   171.960                    1163                    None
# 1214   GOOG  2042.620                      97                    None
# 1336    MYL    16.147                   12386                    None
# 1337    NBL     8.790                   22753                    None
# 1358    NWS    24.530                    8153                    None
# 1373    PEG    61.600                    3246                    None
# 1452   TROW   182.400                    1096                    None
# 1462     UA    18.810                   10632                    None
# 1464    UAL    57.930                    3452                    None
# 1508    XRX    25.040                    7987                    None
#
#      PE Percentile Price-to-Book Ratio PB Percentile Price-to-sales Ratio  \
# 545            N/A                None           N/A                 None
# 547            N/A                None           N/A                 None
# 576            N/A                None           N/A                 None
# 623            N/A                None           N/A                 None
# 641            N/A                None           N/A                 None
# 670            N/A                None           N/A                 None
# 673            N/A                None           N/A                 None
# 695            N/A                None           N/A                 None
# 697            N/A                None           N/A                 None
# 709            N/A                None           N/A                 None
# 831            N/A                None           N/A                 None
# 832            N/A                None           N/A                 None
# 853            N/A                None           N/A                 None
# 868            N/A                None           N/A                 None
# 947            N/A                None           N/A                 None
# 957            N/A                None           N/A                 None
# 959            N/A                None           N/A                 None
# 1003           N/A                None           N/A                 None
# 1050           N/A                None           N/A                 None
# 1052           N/A                None           N/A                 None
# 1081           N/A                None           N/A                 None
# 1128           N/A                None           N/A                 None
# 1146           N/A                None           N/A                 None
# 1175           N/A                None           N/A                 None
# 1178           N/A                None           N/A                 None
# 1200           N/A                None           N/A                 None
# 1202           N/A                None           N/A                 None
# 1214           N/A                None           N/A                 None
# 1336           N/A                None           N/A                 None
# 1337           N/A                None           N/A                 None
# 1358           N/A                None           N/A                 None
# 1373           N/A                None           N/A                 None
# 1452           N/A                None           N/A                 None
# 1462           N/A                None           N/A                 None
# 1464           N/A                None           N/A                 None
# 1508           N/A                None           N/A                 None
#
#      PS Percentile EV/EBITDA EV/EBITDA Percentile EV/GP EV/GP Percentile  \
# 545            N/A       N/A                  N/A   N/A              N/A
# 547            N/A       N/A                  N/A   N/A              N/A
# 576            N/A       N/A                  N/A   N/A              N/A
# 623            N/A       N/A                  N/A   N/A              N/A
# 641            N/A       N/A                  N/A   N/A              N/A
# 670            N/A       N/A                  N/A   N/A              N/A
# 673            N/A       N/A                  N/A   N/A              N/A
# 695            N/A       N/A                  N/A   N/A              N/A
# 697            N/A       N/A                  N/A   N/A              N/A
# 709            N/A       N/A                  N/A   N/A              N/A
# 831            N/A       N/A                  N/A   N/A              N/A
# 832            N/A       N/A                  N/A   N/A              N/A
# 853            N/A       N/A                  N/A   N/A              N/A
# 868            N/A       N/A                  N/A   N/A              N/A
# 947            N/A       N/A                  N/A   N/A              N/A
# 957            N/A       N/A                  N/A   N/A              N/A
# 959            N/A       N/A                  N/A   N/A              N/A
# 1003           N/A       N/A                  N/A   N/A              N/A
# 1050           N/A       N/A                  N/A   N/A              N/A
# 1052           N/A       N/A                  N/A   N/A              N/A
# 1081           N/A       N/A                  N/A   N/A              N/A
# 1128           N/A       N/A                  N/A   N/A              N/A
# 1146           N/A       N/A                  N/A   N/A              N/A
# 1175           N/A       N/A                  N/A   N/A              N/A
# 1178           N/A       N/A                  N/A   N/A              N/A
# 1200           N/A       N/A                  N/A   N/A              N/A
# 1202           N/A       N/A                  N/A   N/A              N/A
# 1214           N/A       N/A                  N/A   N/A              N/A
# 1336           N/A       N/A                  N/A   N/A              N/A
# 1337           N/A       N/A                  N/A   N/A              N/A
# 1358           N/A       N/A                  N/A   N/A              N/A
# 1373           N/A       N/A                  N/A   N/A              N/A
# 1452           N/A       N/A                  N/A   N/A              N/A
# 1462           N/A       N/A                  N/A   N/A              N/A
# 1464           N/A       N/A                  N/A   N/A              N/A
# 1508           N/A       N/A                  N/A   N/A              N/A
#
#      RV Score
# 545       N/A
# 547       N/A
# 576       N/A
# 623       N/A
# 641       N/A
# 670       N/A
# 673       N/A
# 695       N/A
# 697       N/A
# 709       N/A
# 831       N/A
# 832       N/A
# 853       N/A
# 868       N/A
# 947       N/A
# 957       N/A
# 959       N/A
# 1003      N/A
# 1050      N/A
# 1052      N/A
# 1081      N/A
# 1128      N/A
# 1146      N/A
# 1175      N/A
# 1178      N/A
# 1200      N/A
# 1202      N/A
# 1214      N/A
# 1336      N/A
# 1337      N/A
# 1358      N/A
# 1373      N/A
# 1452      N/A
# 1462      N/A
# 1464      N/A
# 1508      N/A

# %%
percentile_columns = ['PE', 'PB', 'PS', 'EV/EBITDA', 'EV/GP']
price_columns = [
#     'Price-to-earnings Ratio',
#     'Price-to-Book Ratio',
#     'Price-to-sales Ratio',
    'EV/EBITDA',
#     'EV/GP'
]

# # To replace None values with 0
# # This needs to be done because stats.percentileofscore throws error when it encounters None
# # However, this correction alters the percentiles, a better solution is needed
# for row in rv_dataframe.index:
#     if rv_dataframe.loc[row, 'Price-to-earnings Ratio'] == None:
#         rv_dataframe.loc[row, 'Price-to-earnings Ratio'] = 0

for column in price_columns:
    rv_dataframe[column].fillna(rv_dataframe[column].mean(), inplace = True)
        
# for row in rv_dataframe.index:
#     for percentile_column in percentile_columns:
#         ratio_col = 'Price-to-earnings Ratio'
#         percentile_col = f'{percentile_column} Percentile'
#         rv_dataframe.loc[row, percentile_col] = score(rv_dataframe[ratio_col], rv_dataframe.loc[row, ratio_col])
# rv_dataframe
rv_dataframe
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-69-f1425e3c25ab> in <module>
#      16
#      17 for column in price_columns:
# ---> 18     rv_dataframe[column].fillna(rv_dataframe[column].mean(), inplace = True)
#      19
#      20 # for row in rv_dataframe.index:
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11116         )
#   11117         def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
# > 11118             return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11119
#   11120         # pandas\core\generic.py:10924: error: Cannot assign to a method
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10724
#   10725     def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
# > 10726         return self._stat_function(
#   10727             "mean", nanops.nanmean, axis, skipna, level, numeric_only, **kwargs
#   10728         )
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/generic.py in _stat_function(self, name, func, axis, skipna, level, numeric_only, **kwargs)
#   10709         if level is not None:
#   10710             return self._agg_by_level(name, axis=axis, level=level, skipna=skipna)
# > 10711         return self._reduce(
#   10712             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   10713         )
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4180                 )
#    4181             with np.errstate(all="ignore"):
# -> 4182                 return op(delegate, skipna=skipna, **kwds)
#    4183
#    4184     def _reindex_indexer(self, new_index, indexer, copy):
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      69             try:
#      70                 with np.errstate(invalid="ignore"):
# ---> 71                     return f(*args, **kwargs)
#      72             except ValueError as e:
#      73                 # we want to transform an object array
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     131                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     132             else:
# --> 133                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     134
#     135             return result
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/nanops.py in new_func(values, axis, skipna, mask, **kwargs)
#     390             mask = isna(values)
#     391
# --> 392         result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     393
#     394         if datetimelike:
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/nanops.py in nanmean(values, axis, skipna, mask)
#     629
#     630     count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 631     the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     632
#     633     if axis is not None and getattr(the_sum, "ndim", False):
#
# /opt/conda/lib/python3.8/site-packages/numpy/core/_methods.py in _sum(a, axis, dtype, out, keepdims, initial, where)
#      45 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      46          initial=_NoValue, where=True):
# ---> 47     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#      48
#      49 def _prod(a, axis=None, dtype=None, out=None, keepdims=False,
#
# TypeError: unsupported operand type(s) for +: 'float' and 'str'
